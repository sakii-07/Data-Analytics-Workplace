# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
month = ['jan','feb','mar','apr']
sales_2023 = [11,22,13,24]
sales_2024 = [10,20,14,25]
sales_2025 = [14,23,24,35]

plt.subplot(2,2,1)
plt.plot(month,sales_2023)

plt.subplot(2,2,2)
plt.plot(month,sales_2024)


plt.subplot(2,2,3)
plt.plot(month,sales_2025)
plt.show()
