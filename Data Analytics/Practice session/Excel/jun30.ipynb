# %%
# Python Data Analytics Test
## Topic: NumPy, Pandas & Matplotlib
**Total Marks:** 20
**Time:** 45 Minutes

### Instructions:
- Answer all questions.
- Write Python code wherever required.
- Use proper syntax and comments.
- Each question carries 2 marks.

------------------------------------------------------------

Q1. Explain NumPy. Why is NumPy preferred over Python Lists for numerical computations? Mention any four advantages.

(2 Marks)

------------------------------------------------------------

Q2. Explain the following NumPy functions with suitable examples:
- array()
- arange()
- linspace()
- reshape()

(2 Marks)

------------------------------------------------------------

Q3. What is a Pandas DataFrame? Explain the difference between a Pandas Series and a DataFrame with suitable examples.

(2 Marks)

------------------------------------------------------------

Q4. You are given a CSV file named employees.csv.

Write Python code to:
- Load the CSV file into a DataFrame.
- Display the first five records.
- Display the last five records.
- Display information about the DataFrame.

(2 Marks)

------------------------------------------------------------

Q5. Write Python code to perform the following operations on a DataFrame:
- Select a single column.
- Select multiple columns.
- Filter records where Salary is greater than 50,000.
- Sort the data by Salary in descending order.

(2 Marks)

------------------------------------------------------------

Q6. Explain the purpose of the following Pandas functions with suitable examples:
- head()
- tail()
- describe()
- info()

(2 Marks)

------------------------------------------------------------

Q7. Explain data cleaning in Pandas. Write Python code to:
- Find missing values.
- Remove missing values.
- Replace missing values with a default value.

(2 Marks)

------------------------------------------------------------

Q8. Explain Matplotlib. Write Python code to create:
- A Line Chart
- A Bar Chart
- A Pie Chart

Also mention one real-world use case for each chart.

(2 Marks)

------------------------------------------------------------

Q9. A company has the following monthly sales data:

Month   Sales
Jan     120
Feb     150
Mar     180
Apr     170
May     220

Write Python code using Pandas and Matplotlib to:
- Create a DataFrame.
- Plot a Line Chart.
- Add a chart title.
- Label both axes.
- Display the chart.

(2 Marks)

------------------------------------------------------------

Q10. You are working as a Data Analyst in a finance company.

You receive a CSV file containing the following columns:
- Customer_ID
- Customer_Name
- Loan_Amount
- Branch
- Loan_Status

Write the complete Python steps (with code where applicable) to:
- Load the dataset.
- Display basic information.
- Check for missing values.
- Display summary statistics.
- Find the average loan amount.
- Display the top 5 customers with the highest loan amount.
- Create a bar chart showing the number of customers in each branch.

(2 Marks)

------------------------------------------------------------

Total Marks: 20
